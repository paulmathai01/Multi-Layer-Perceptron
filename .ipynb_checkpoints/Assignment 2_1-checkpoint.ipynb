# %%
# Importing required libraries
import pandas as pd                                   
import numpy as np                                    
import keras
from keras.models import Sequential                   
from keras.layers import Dense, Activation            
from keras.callbacks import History 
from sklearn.metrics import confusion_matrix          
from sklearn import preprocessing
from sklearn.model_selection import train_test_split  
from sklearn.preprocessing import LabelBinarizer    
from sklearn.model_selection import KFold
import seaborn as sns                                 
import matplotlib.pyplot as plt                       
# %matplotlib inline

np.random.seed(1)
# Out:
# /Users/paulmathai/.virtualenvs/keras_tf/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Load dataset from Keras
#KEEP DATA IN THE SAME DIRECTORY ***RELATIVE FILE PATH***
data = np.loadtxt("SPC-Datasets/SPC-Training.txt")
data2 = np.loadtxt("SPC-Datasets/SPC-Testing.txt")

# %%
# Shaping the Dataset for single run and Kfold run
(X_train, y_train), (X_test, y_test) =(data[:, 0:10], data[:, 10:17]), (data2[:, 0:10], data2[:, 10:17])

# %%
# Normalize x
X_train = X_train.astype(float) / np.amax(X_train)
X_test = X_test.astype(float) / np.amax(X_test)

# Flatten input: Changing dimension of input
X_train = X_train.reshape([X_train.shape[0], -1])
X_test = X_test.reshape([X_test.shape[0], -1])

# Transforming y using Label Binarizer from Scikit Learn
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# Printing dimensions
print("Shape of X_train", X_train.shape)
print("Shape of y_train", y_train.shape)
    
# Splitting training data in training and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 10)
# Out:
# Shape of X_train (2500, 10)
# Shape of y_train (2500, 7)

# %%
i_nodes = X_train.shape[1]
h_nodes_1 = 512
h_nodes_2 = 256
o_nodes = y_train.shape[1]

# %%
model = Sequential()
history = History()
model.add(Dense(h_nodes_1, input_dim = i_nodes, kernel_initializer = 'normal', activation = 'relu'))    # Hidden Layer 1
model.add(Dense(h_nodes_2, kernel_initializer = 'normal', activation = 'relu'))                         # Hidden Layer 2
model.add(Dense(o_nodes, kernel_initializer = 'normal', activation = 'softmax'))                        # Output Layer
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])            # Compile Model

# Train Model
history = model.fit(X_train, y_train, epochs = 40, validation_data=(X_val, y_val))                     # Train Model

# Model Predictions
y_predict = model.predict_classes(X_test)

# Evaluate Model
Test_Loss, Test_Accuracy = model.evaluate(X_test, y_test)
Train_Loss, Train_Accuracy = model.evaluate(X_train, y_train)
val_Loss, val_Accuracy = model.evaluate(X_val, y_val)
# Out:
# Train on 2000 samples, validate on 500 samples
# Epoch 1/40
# 2000/2000 [==============================] - 0s 153us/step - loss: 1.6729 - accuracy: 0.3925 - val_loss: 1.4716 - val_accuracy: 0.4100
# Epoch 2/40
# 2000/2000 [==============================] - 0s 83us/step - loss: 1.1581 - accuracy: 0.5800 - val_loss: 0.8464 - val_accuracy: 0.7240
# Epoch 3/40
# 2000/2000 [==============================] - 0s 89us/step - loss: 0.6571 - accuracy: 0.7675 - val_loss: 0.5695 - val_accuracy: 0.7960
# Epoch 4/40
# 2000/2000 [==============================] - 0s 82us/step - loss: 0.4648 - accuracy: 0.8470 - val_loss: 0.4129 - val_accuracy: 0.8520
# Epoch 5/40
# 2000/2000 [==============================] - 0s 82us/step - loss: 0.3641 - accuracy: 0.8895 - val_loss: 0.3520 - val_accuracy: 0.8600
n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplots(nrows=1, ncols=1)
    plt.tight_layout()
    
    plt.plot(history.epoch,  history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],linestyle="--", label='Val')
    
    plt.xlabel('Epoch')
    plt.ylabel(name)
    plt.legend()

# %%
# Getting Prediction Accuracies               
print("Test Accuracy is: ", (round((Test_Accuracy * 100), 2)),"%")
print("Test Loss is: ", round(Test_Loss*100,2),"%")
# Out:
# Test Accuracy is:  92.0 %
# Test Loss is:  27.08 %

# %%
# Making a confustion Matrix
y_test_list = []
for rows in y_test:
    label = np.argmax(rows)
    y_test_list.append(label)
y_test = np.asarray(y_test_list);

cm = confusion_matrix(y_test, y_predict)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5,51,'Predicted label')

# %%
count = 1;
kfold = KFold(3, True, 1)
for train, test in kfold.split(data):
    ([current_fold_train,current_fold_test]) = (data[train], data[test])
    print("Fold %d " % count)
    print(train)
    print('train: %s, test: %s' % (current_fold_train,current_fold_test))
    count +=1
    X_train, X_val, y_train, y_val = train_test_split(current_fold_train[:, 0:10], current_fold_train[:, 10:17], test_size = 0.2, random_state = 10)
    print("Shape of X_train", X_train.shape)
    print("Shape of y_train", y_train.shape)
    i_nodes = X_train.shape[1]
    h_nodes_1 = 64
    h_nodes_2 = 32
    h_nodes_3 = 16
    o_nodes = y_train.shape[1]
    model = Sequential()
    history = History()
    model.add(Dense(h_nodes_1, input_dim = i_nodes, kernel_initializer = 'normal', activation = 'relu'))    # Hidden Layer 1
    model.add(Dense(h_nodes_2, kernel_initializer = 'normal', activation = 'relu'))                         # Hidden Layer 2
    model.add(Dense(h_nodes_3, kernel_initializer = 'normal', activation = 'relu'))
    model.add(Dense(o_nodes, kernel_initializer = 'normal', activation = 'softmax'))                        # Output Layer
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])            # Compile Model

    # Train Model
    history = model.fit(X_train, y_train, epochs = 40, validation_data=(X_val, y_val))                     # Train Model
    # Model Predictions
    #y_predict = model.predict_classes(X_test)
    print("Shape of X_test", X_test.shape)
    print("Shape of y_test", y_test.shape)
    # Evaluate Model
    #y_test = y_test.reshape(78,1)
    #Test_Loss, Test_Accuracy = model.evaluate(X_test, y_test1)
    Train_Loss, Train_Accuracy = model.evaluate(X_train, y_train)
    val_Loss, val_Accuracy = model.evaluate(X_val, y_val)
    
    print("Training Loss and Training Accuracy",round(Train_Loss*100,2),"%", round(Train_Accuracy*100,2),"%")
    print("Validattion Loss and Validation Accuracy",round(val_Loss*100,2),"%", round(val_Accuracy*100,2),"%")
    print("Test Loss and Test Accuracy",round(Test_Loss*100,2),"%",round(Test_Accuracy*100,2),"%" )
# Out:
# Fold 1
# [   0    2    5 ... 2493 2494 2495]
# train: [[-1.691 -2.426  1.44  ...  0.     0.     0.   ]
#  [-0.278  0.169 -2.756 ...  0.     0.     0.   ]
# Test Loss and Test Accuracy 27.08 % 92.0 %
# Fold 2
# [   1    3    4 ... 2497 2498 2499]
# train: [[ 1.337 -0.014 -1.134 ...  0.     0.     0.   ]
#  [ 1.156  1.827  1.084 ...  0.     0.     0.   ]
#  [-2.849 -2.715  0.909 ...  0.     0.     0.   ]
#  ...
#  [ 0.679  0.069  0.841 ...  0.     0.     1.   ]
#  [ 0.948 -0.725  0.262 ...  0.     0.     1.   ]
#  [-0.056 -1.581 -0.315 ...  0.     0.     1.   ]], test: [[-1.691 -2.426  1.44  ...  0.     0.     0.   ]
#  [-0.278  0.169 -2.756 ...  0.     0.     0.   ]
#  [ 1.217 -1.706  2.268 ...  0.     0.     0.   ]
#  ...
#  [-0.2   -0.901 -2.563 ...  0.     0.     1.   ]
#  [-0.08   1.72  -0.067 ...  0.     0.     1.   ]
#  [ 0.658 -0.899 -0.362 ...  0.     0.     1.   ]]
# Shape of X_train (1333, 10)
# Shape of y_train (1333, 7)
# Train on 1333 samples, validate on 334 samples
# Epoch 1/40
# 1333/1333 [==============================] - 0s 129us/step - loss: 1.9233 - accuracy: 0.3863 - val_loss: 1.8781 - val_accuracy: 0.3743
# Epoch 2/40
# 1333/1333 [==============================] - 0s 36us/step - loss: 1.7558 - accuracy: 0.3998 - val_loss: 1.7377 - val_accuracy: 0.3743
# Epoch 3/40
# 1333/1333 [==============================] - 0s 32us/step - loss: 1.6611 - accuracy: 0.3998 - val_loss: 1.6901 - val_accuracy: 0.3743
# Epoch 4/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.5964 - accuracy: 0.3998 - val_loss: 1.6287 - val_accuracy: 0.3743
# Epoch 5/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.5165 - accuracy: 0.3998 - val_loss: 1.5446 - val_accuracy: 0.3743
# Epoch 6/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 1.4383 - accuracy: 0.4021 - val_loss: 1.4850 - val_accuracy: 0.3802
# Epoch 7/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.3748 - accuracy: 0.4276 - val_loss: 1.4218 - val_accuracy: 0.4341
# Epoch 8/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 1.3180 - accuracy: 0.4741 - val_loss: 1.3749 - val_accuracy: 0.4581
# Epoch 9/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 1.2437 - accuracy: 0.5101 - val_loss: 1.3070 - val_accuracy: 0.4641
# Epoch 10/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 1.1452 - accuracy: 0.5364 - val_loss: 1.1836 - val_accuracy: 0.5180
# Epoch 11/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.0361 - accuracy: 0.5604 - val_loss: 1.1017 - val_accuracy: 0.5120
# Epoch 12/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.9342 - accuracy: 0.5956 - val_loss: 1.0032 - val_accuracy: 0.5449
# Epoch 13/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.8578 - accuracy: 0.6287 - val_loss: 0.9311 - val_accuracy: 0.5868
# Epoch 14/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.7939 - accuracy: 0.6527 - val_loss: 0.8873 - val_accuracy: 0.5778
# Epoch 15/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.7395 - accuracy: 0.6932 - val_loss: 0.8309 - val_accuracy: 0.6617
# Epoch 16/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.6903 - accuracy: 0.7494 - val_loss: 0.7582 - val_accuracy: 0.7066
# Epoch 17/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.6399 - accuracy: 0.7959 - val_loss: 0.7257 - val_accuracy: 0.7365
# Epoch 18/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.5901 - accuracy: 0.8237 - val_loss: 0.6927 - val_accuracy: 0.7545
# Epoch 19/40
# 1333/1333 [==============================] - 0s 32us/step - loss: 0.5546 - accuracy: 0.8305 - val_loss: 0.6731 - val_accuracy: 0.7275
# Epoch 20/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.5144 - accuracy: 0.8350 - val_loss: 0.5932 - val_accuracy: 0.7635
# Epoch 21/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.4754 - accuracy: 0.8500 - val_loss: 0.5839 - val_accuracy: 0.7575
# Epoch 22/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.4456 - accuracy: 0.8515 - val_loss: 0.5389 - val_accuracy: 0.7814
# Epoch 23/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.4192 - accuracy: 0.8590 - val_loss: 0.5535 - val_accuracy: 0.7754
# Epoch 24/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.3946 - accuracy: 0.8612 - val_loss: 0.5662 - val_accuracy: 0.7665
# Epoch 25/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.3747 - accuracy: 0.8800 - val_loss: 0.4865 - val_accuracy: 0.8024
# Epoch 26/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.3603 - accuracy: 0.8770 - val_loss: 0.4850 - val_accuracy: 0.8174
# Epoch 27/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.3479 - accuracy: 0.8815 - val_loss: 0.5024 - val_accuracy: 0.7814
# Epoch 28/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.3281 - accuracy: 0.8935 - val_loss: 0.4449 - val_accuracy: 0.8234
# Epoch 29/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.3025 - accuracy: 0.9070 - val_loss: 0.4698 - val_accuracy: 0.8174
# Epoch 30/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2986 - accuracy: 0.9040 - val_loss: 0.4308 - val_accuracy: 0.8204
# Epoch 31/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 0.2852 - accuracy: 0.9100 - val_loss: 0.4387 - val_accuracy: 0.8263
# Epoch 32/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2772 - accuracy: 0.9145 - val_loss: 0.4370 - val_accuracy: 0.8114
# Epoch 33/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2615 - accuracy: 0.9227 - val_loss: 0.4141 - val_accuracy: 0.8263
# Epoch 34/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2632 - accuracy: 0.9205 - val_loss: 0.4315 - val_accuracy: 0.8293
# Epoch 35/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2416 - accuracy: 0.9250 - val_loss: 0.4302 - val_accuracy: 0.8204
# Epoch 36/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2399 - accuracy: 0.9250 - val_loss: 0.4179 - val_accuracy: 0.8323
# Epoch 37/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.2315 - accuracy: 0.9212 - val_loss: 0.4079 - val_accuracy: 0.8353
# Epoch 38/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.2248 - accuracy: 0.9235 - val_loss: 0.4111 - val_accuracy: 0.8323
# Epoch 39/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2204 - accuracy: 0.9340 - val_loss: 0.3908 - val_accuracy: 0.8383
# Epoch 40/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.2164 - accuracy: 0.9317 - val_loss: 0.4088 - val_accuracy: 0.8443
# Shape of X_test (250, 10)
# Shape of y_test (250,)
# 1333/1333 [==============================] - 0s 11us/step
# 334/334 [==============================] - 0s 16us/step
# Training Loss and Training Accuracy 19.78 % 94.6 %
# Validattion Loss and Validation Accuracy 40.88 % 84.43 %
# Test Loss and Test Accuracy 27.08 % 92.0 %
# Fold 3
# [   0    1    2 ... 2497 2498 2499]
# train: [[-1.691 -2.426  1.44  ...  0.     0.     0.   ]
#  [ 1.337 -0.014 -1.134 ...  0.     0.     0.   ]
#  [-0.278  0.169 -2.756 ...  0.     0.     0.   ]
#  ...
#  [ 0.679  0.069  0.841 ...  0.     0.     1.   ]
#  [ 0.948 -0.725  0.262 ...  0.     0.     1.   ]
#  [-0.056 -1.581 -0.315 ...  0.     0.     1.   ]], test: [[-0.433 -0.183  2.558 ...  0.     0.     0.   ]
#  [ 1.622  1.609 -1.191 ...  0.     0.     0.   ]
#  [-2.053 -2.507  0.599 ...  0.     0.     0.   ]
#  ...
#  [ 0.941 -0.364 -0.627 ...  0.     0.     1.   ]
#  [ 0.57   0.814  0.833 ...  0.     0.     1.   ]
#  [-0.728  0.085  0.526 ...  0.     0.     1.   ]]
# Shape of X_train (1333, 10)
# Shape of y_train (1333, 7)
# Train on 1333 samples, validate on 334 samples
# Epoch 1/40
# 1333/1333 [==============================] - 0s 127us/step - loss: 1.9193 - accuracy: 0.3908 - val_loss: 1.8550 - val_accuracy: 0.3802
# Epoch 2/40
# 1333/1333 [==============================] - 0s 35us/step - loss: 1.7437 - accuracy: 0.4014 - val_loss: 1.7113 - val_accuracy: 0.3802
# Epoch 3/40
# 1333/1333 [==============================] - 0s 32us/step - loss: 1.6654 - accuracy: 0.4014 - val_loss: 1.6800 - val_accuracy: 0.3802
# Epoch 4/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 1.6203 - accuracy: 0.4014 - val_loss: 1.6235 - val_accuracy: 0.3802
# Epoch 5/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 1.5530 - accuracy: 0.4074 - val_loss: 1.5370 - val_accuracy: 0.4371
# Epoch 6/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.4731 - accuracy: 0.4839 - val_loss: 1.4650 - val_accuracy: 0.4910
# Epoch 7/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.3958 - accuracy: 0.5191 - val_loss: 1.3943 - val_accuracy: 0.5389
# Epoch 8/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.3172 - accuracy: 0.5476 - val_loss: 1.3279 - val_accuracy: 0.5389
# Epoch 9/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.2336 - accuracy: 0.5814 - val_loss: 1.2569 - val_accuracy: 0.5749
# Epoch 10/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.1583 - accuracy: 0.6017 - val_loss: 1.2072 - val_accuracy: 0.5719
# Epoch 11/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.0808 - accuracy: 0.6167 - val_loss: 1.0997 - val_accuracy: 0.5838
# Epoch 12/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 1.0023 - accuracy: 0.6384 - val_loss: 1.0365 - val_accuracy: 0.6198
# Epoch 13/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.9218 - accuracy: 0.6467 - val_loss: 0.9487 - val_accuracy: 0.6617
# Epoch 14/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.8500 - accuracy: 0.6842 - val_loss: 0.9013 - val_accuracy: 0.6497
# Epoch 15/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.7642 - accuracy: 0.7149 - val_loss: 0.8067 - val_accuracy: 0.6946
# Epoch 16/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.6825 - accuracy: 0.7584 - val_loss: 0.7241 - val_accuracy: 0.7455
# Epoch 17/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.6045 - accuracy: 0.7959 - val_loss: 0.6807 - val_accuracy: 0.7365
# Epoch 18/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.5532 - accuracy: 0.7989 - val_loss: 0.6051 - val_accuracy: 0.7784
# Epoch 19/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.5023 - accuracy: 0.8222 - val_loss: 0.5720 - val_accuracy: 0.7844
# Epoch 20/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.4542 - accuracy: 0.8455 - val_loss: 0.5281 - val_accuracy: 0.8084
# Epoch 21/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.4322 - accuracy: 0.8455 - val_loss: 0.4824 - val_accuracy: 0.8234
# Epoch 22/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.3909 - accuracy: 0.8732 - val_loss: 0.4666 - val_accuracy: 0.8234
# Epoch 23/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.3713 - accuracy: 0.8777 - val_loss: 0.4467 - val_accuracy: 0.8234
# Epoch 24/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.3539 - accuracy: 0.8860 - val_loss: 0.4405 - val_accuracy: 0.8293
# Epoch 25/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.3326 - accuracy: 0.8897 - val_loss: 0.4130 - val_accuracy: 0.8473
# Epoch 26/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.3205 - accuracy: 0.9002 - val_loss: 0.4005 - val_accuracy: 0.8443
# Epoch 27/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.3086 - accuracy: 0.9010 - val_loss: 0.3849 - val_accuracy: 0.8593
# Epoch 28/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2957 - accuracy: 0.9025 - val_loss: 0.3934 - val_accuracy: 0.8503
# Epoch 29/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2783 - accuracy: 0.9010 - val_loss: 0.3919 - val_accuracy: 0.8533
# Epoch 30/40
# 1333/1333 [==============================] - 0s 32us/step - loss: 0.2722 - accuracy: 0.9092 - val_loss: 0.3944 - val_accuracy: 0.8473
# Epoch 31/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2644 - accuracy: 0.9092 - val_loss: 0.3616 - val_accuracy: 0.8743
# Epoch 32/40
# 1333/1333 [==============================] - 0s 30us/step - loss: 0.2610 - accuracy: 0.9160 - val_loss: 0.3869 - val_accuracy: 0.8593
# Epoch 33/40
# 1333/1333 [==============================] - 0s 31us/step - loss: 0.2446 - accuracy: 0.9235 - val_loss: 0.3649 - val_accuracy: 0.8563
# Epoch 34/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2354 - accuracy: 0.9302 - val_loss: 0.3708 - val_accuracy: 0.8623
# Epoch 35/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2292 - accuracy: 0.9287 - val_loss: 0.3519 - val_accuracy: 0.8653
# Epoch 36/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2190 - accuracy: 0.9355 - val_loss: 0.3334 - val_accuracy: 0.8683
# Epoch 37/40
# 1333/1333 [==============================] - 0s 28us/step - loss: 0.2253 - accuracy: 0.9302 - val_loss: 0.3430 - val_accuracy: 0.8743
# Epoch 38/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2123 - accuracy: 0.9347 - val_loss: 0.3435 - val_accuracy: 0.8653
# Epoch 39/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.2086 - accuracy: 0.9362 - val_loss: 0.3355 - val_accuracy: 0.8683
# Epoch 40/40
# 1333/1333 [==============================] - 0s 29us/step - loss: 0.1934 - accuracy: 0.9422 - val_loss: 0.3337 - val_accuracy: 0.8713
# Shape of X_test (250, 10)
# Shape of y_test (250,)
# 1333/1333 [==============================] - 0s 11us/step
# 334/334 [==============================] - 0s 15us/step
# Training Loss and Training Accuracy 18.29 % 94.67 %
# Validattion Loss and Validation Accuracy 33.37 % 87.13 %
# Test Loss and Test Accuracy 27.08 % 92.0 %

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       100
#            1       0.96      0.96      0.96        25
#            2       0.78      0.84      0.81        25
#            3       0.82      0.72      0.77        25
#            4       0.91      0.84      0.87        25
#            5       1.00      1.00      1.00        25
#            6       1.00      0.92      0.96        25
#
#     accuracy                           0.92       250
#    macro avg       0.91      0.89      0.90       250
# weighted avg       0.92      0.92      0.92       250
