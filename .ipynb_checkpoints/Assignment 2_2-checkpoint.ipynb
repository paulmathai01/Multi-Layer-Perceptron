# %%
# Importing required libraries
import pandas as pd                                 
import numpy as np                                    
import keras
from keras.models import Sequential                  
from keras.layers import Dense, Activation             
from keras.callbacks import History 
from sklearn.metrics import confusion_matrix         
from sklearn import preprocessing
from sklearn.model_selection import train_test_split  
from sklearn.preprocessing import LabelBinarizer  
from sklearn.model_selection import KFold
import seaborn as sns                                 
import matplotlib.pyplot as plt                       
# %matplotlib inline
np.random.seed(0)
# Out:
# /Users/paulmathai/.virtualenvs/keras_tf/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Load dataset from Keras
#KEEP DATA IN THE SAME DIRECTORY ***RELATIVE FILE PATH***
data = np.loadtxt("mfcr_train.txt")
data2 = np.loadtxt("mfcr_test.txt")

# %%
(X_train, y_train), (X_test, y_test) =(data[:, 0:14], data[:, 14:40]), (data2[:, 0:14], data2[:, 14:40])

# %%
# Normalize x
X_train = X_train.astype(float) / np.amax(X_train)
X_test = X_test.astype(float) / np.amax(X_test)

# Flatten input: Changing dimension of input images from N*28*28 to N*784
X_train = X_train.reshape([X_train.shape[0], -1])
X_test = X_test.reshape([X_test.shape[0], -1])

# Transforming y using Label Binarizer from Scikit Learn
lb = LabelBinarizer()
y_test1 =  data2[:, 14:40]
y_train = lb.fit_transform(y_train)
y_test_1  = y_test
y_test = lb.fit_transform(y_test)


# Printing dimensions
print("Shape of X_train", X_train.shape)
print("Shape of y_train", y_train.shape)
    
# Splitting training data in training and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 10)
# Out:
# Shape of X_train (78, 14)
# Shape of y_train (78, 26)

# %%
i_nodes = 14
h_nodes_1 = 512
h_nodes_2 = 256
o_nodes = 26

# %%
model = Sequential()
history = History()
model.add(Dense(h_nodes_1, input_dim = i_nodes, kernel_initializer = 'normal', activation = 'relu'))    # Hidden Layer 1
model.add(Dense(h_nodes_2, kernel_initializer = 'normal', activation = 'relu'))                         # Hidden Layer 2
model.add(Dense(o_nodes, kernel_initializer = 'normal', activation = 'softmax'))                        # Output Layer
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])            # Compile Model
# Train Model
history = model.fit(X_train, y_train, epochs = 100, validation_data=(X_val, y_val))                     # Train Model
# Model Predictions
y_predict = model.predict_classes(X_test)
# Evaluate Model
Test_Loss, Test_Accuracy = model.evaluate(X_test, y_test)
Train_Loss, Train_Accuracy = model.evaluate(X_train, y_train)
val_Loss, val_Accuracy = model.evaluate(X_val, y_val)
# Out:
# Train on 62 samples, validate on 16 samples
# Epoch 1/100
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2574 - accuracy: 0.0968 - val_loss: 3.2510 - val_accuracy: 0.0625
# Epoch 2/100
# 62/62 [==============================] - 0s 116us/step - loss: 3.2402 - accuracy: 0.2742 - val_loss: 3.2516 - val_accuracy: 0.0625
# Epoch 3/100
# 62/62 [==============================] - 0s 119us/step - loss: 3.2265 - accuracy: 0.3065 - val_loss: 3.2527 - val_accuracy: 0.1250
# Epoch 4/100
# 62/62 [==============================] - 0s 116us/step - loss: 3.2113 - accuracy: 0.3548 - val_loss: 3.2524 - val_accuracy: 0.1250
# Epoch 5/100
# 62/62 [==============================] - 0s 114us/step - loss: 3.1955 - accuracy: 0.3710 - val_loss: 3.2514 - val_accuracy: 0.1250
# Epoch 6/100
# 62/62 [==============================] - 0s 116us/step - loss: 3.1766 - accuracy: 0.4194 - val_loss: 3.2509 - val_accuracy: 0.1250
# Epoch 7/100
# Epoch 93/100
# 62/62 [==============================] - 0s 134us/step - loss: 0.1901 - accuracy: 0.9839 - val_loss: 4.3769 - val_accuracy: 0.5625
# Epoch 94/100
# 62/62 [==============================] - 0s 129us/step - loss: 0.1847 - accuracy: 0.9839 - val_loss: 4.4006 - val_accuracy: 0.5625
# Epoch 95/100
# 62/62 [==============================] - 0s 122us/step - loss: 0.1778 - accuracy: 0.9839 - val_loss: 4.4155 - val_accuracy: 0.5625
# Epoch 96/100
# 62/62 [==============================] - 0s 123us/step - loss: 0.1743 - accuracy: 0.9839 - val_loss: 4.4475 - val_accuracy: 0.5625
# Epoch 97/100
# 62/62 [==============================] - 0s 127us/step - loss: 0.1711 - accuracy: 0.9839 - val_loss: 4.4560 - val_accuracy: 0.5625
# Epoch 98/100
# 62/62 [==============================] - 0s 120us/step - loss: 0.1643 - accuracy: 0.9839 - val_loss: 4.4752 - val_accuracy: 0.5625
# Epoch 99/100
# 62/62 [==============================] - 0s 122us/step - loss: 0.1607 - accuracy: 0.9839 - val_loss: 4.4916 - val_accuracy: 0.5625
# Epoch 100/100
# 62/62 [==============================] - 0s 119us/step - loss: 0.1565 - accuracy: 0.9839 - val_loss: 4.5193 - val_accuracy: 0.5625
# 78/78 [==============================] - 0s 42us/step
# 62/62 [==============================] - 0s 42us/step
# 16/16 [==============================] - 0s 45us/step

# %%
print("Training Loss is: ", round(Train_Loss*100,2),"%")
print("Training Accuracy is: ", round(Train_Accuracy*100,2),"%")
print("val Loss is: ", round(val_Loss*100,2),"%")
print("val Accuracy is: ", round(val_Accuracy*100,2),"%")
# Out:
# Training Loss is:  15.23 %
# Training Accuracy is:  98.39 %
# val Loss is:  451.93 %
# val Accuracy is:  56.25 %

# %%
metrics =  ['loss', 'accuracy']
for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplots(nrows=1, ncols=1)
    plt.tight_layout()
    
    plt.plot(history.epoch,  history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],linestyle="--", label='Val')
    
    plt.xlabel('Epoch')
    plt.ylabel(name)
    plt.legend()

# %%
# Getting Prediction Accuracies               
print("Test Accuracy is: ", (round((Test_Accuracy * 100), 2)),"%")
print("Test Loss is: ", round(Test_Loss*100,2),"%")
# Out:
# Test Accuracy is:  76.92 %
# Test Loss is:  168.51 %

# %%
# Making a confustion Matrix
y_test_list = []
for rows in y_test:
    label = np.argmax(rows)
    y_test_list.append(label)
y_test = np.asarray(y_test_list);

cm = confusion_matrix(y_test, y_predict)
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5,51,'Predicted label')

# %%
count = 1;
kfold = KFold(3, True, 1)
for train, test in kfold.split(data):
    ([current_fold_train,current_fold_test]) = (data[train], data[test])
    print("Fold %d " % count)
    print(train)
    print('train: %s, test: %s' % (current_fold_train,current_fold_test))
    count +=1
    X_train, X_val, y_train, y_val = train_test_split(current_fold_train[:, 0:14], current_fold_train[:, 14:26], test_size = 0.2, random_state = 10)
    print("Shape of X_train", X_train.shape)
    print("Shape of y_train", y_train.shape)
    i_nodes = X_train.shape[1]
    h_nodes_1 = 64
    h_nodes_2 = 32
    h_nodes_3 = 16
    o_nodes = y_train.shape[1]
    model = Sequential()
    history = History()
    model.add(Dense(h_nodes_1, input_dim = i_nodes, kernel_initializer = 'normal', activation = 'relu'))    # Hidden Layer 1
    model.add(Dense(h_nodes_2, kernel_initializer = 'normal', activation = 'relu'))                         # Hidden Layer 2
    model.add(Dense(h_nodes_3, kernel_initializer = 'normal', activation = 'relu'))
    model.add(Dense(o_nodes, kernel_initializer = 'normal', activation = 'softmax'))                        # Output Layer
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])            # Compile Model

    # Train Model
    history = model.fit(X_train, y_train, epochs = 40, validation_data=(X_val, y_val))                     # Train Model
    # Model Predictions
    #y_predict = model.predict_classes(X_test)
    print("Shape of X_test", X_test.shape)
    print("Shape of y_test", y_test.shape)
    # Evaluate Model
    #y_test = y_test.reshape(78,1)
    #Test_Loss, Test_Accuracy = model.evaluate(X_test, y_test1)
    Train_Loss, Train_Accuracy = model.evaluate(X_train, y_train)
    val_Loss, val_Accuracy = model.evaluate(X_val, y_val)
    
    print("Training Loss and Training Accuracy",round(Train_Loss*100,2),"%", round(Train_Accuracy*100,2),"%")
    print("Validattion Loss and Validation Accuracy",round(val_Loss*100,2),"%", round(val_Accuracy*100,2),"%")
    print("Test Loss and Test Accuracy",round(Test_Loss*100,2),"%",round(Test_Accuracy*100,2),"%" )
# Out:
# Fold 1
# [ 0  1  3  4  5  6  7  8  9 11 12 13 14 16 17 18 20 21 22 23 24 25 26 28
#  29 30 32 35 37 40 41 42 46 48 49 50 52 53 54 56 57 58 60 62 64 67 69 70
#  72 74 75 76]
# train: [[ 8.  0.  0. ...  0.  0.  0.]
#  [ 7.  0.  0. ...  0.  0.  0.]
#  [21. 10.  4. ...  0.  0.  0.]
#  ...
#  [ 0.  5.  6. ...  0.  1.  0.]
#  [18.  0.  0. ...  0.  0.  1.]
#  [18.  0.  0. ...  0.  0.  1.]], test: [[12. 10.  1. ...  0.  0.  0.]
#  [10. 18.  3. ...  0.  0.  0.]
#  [14.  9.  0. ...  0.  0.  0.]
#  ...
#  [ 0.  2.  8. ...  1.  0.  0.]
#  [ 0. 10.  3. ...  0.  1.  0.]
#  [22.  0.  0. ...  0.  0.  1.]]
# Shape of X_train (41, 14)
# Shape of y_train (41, 12)
# Train on 41 samples, validate on 11 samples
# Epoch 1/40
# 41/41 [==============================] - 0s 3ms/step - loss: 1.3330 - accuracy: 0.0732 - val_loss: 1.3548 - val_accuracy: 0.1818
# Epoch 2/40
# 41/41 [==============================] - 0s 114us/step - loss: 1.3321 - accuracy: 0.0488 - val_loss: 1.3550 - val_accuracy: 0.0909
# Epoch 3/40
# 41/41 [==============================] - 0s 130us/step - loss: 1.3312 - accuracy: 0.0000e+00 - val_loss: 1.3552 - val_accuracy: 0.0909
# Epoch 4/40
# 41/41 [==============================] - 0s 128us/step - loss: 1.3302 - accuracy: 0.0488 - val_loss: 1.3553 - val_accuracy: 0.0000e+00
# Epoch 5/40
# 41/41 [==============================] - 0s 119us/step - loss: 1.3294 - accuracy: 0.0732 - val_loss: 1.3554 - val_accuracy: 0.0000e+00
# Epoch 6/40
# 41/41 [==============================] - 0s 120us/step - loss: 1.3283 - accuracy: 0.0732 - val_loss: 1.3554 - val_accuracy: 0.0000e+00
# Epoch 7/40
# 41/41 [==============================] - 0s 129us/step - loss: 1.3271 - accuracy: 0.0732 - val_loss: 1.3554 - val_accuracy: 0.0000e+00
# Epoch 8/40
# 41/41 [==============================] - 0s 121us/step - loss: 1
40
# 41/41 [==============================] - 0s 116us/step - loss: 1.1813 - accuracy: 0.0488 - val_loss: 1.8210 - val_accuracy: 0.0909
# Epoch 36/40
# 41/41 [==============================] - 0s 124us/step - loss: 1.1697 - accuracy: 0.0488 - val_loss: 1.8893 - val_accuracy: 0.0909
# Epoch 37/40
# 41/41 [==============================] - 0s 118us/step - loss: 1.1569 - accuracy: 0.0488 - val_loss: 1.9661 - val_accuracy: 0.0909
# Epoch 38/40
# 41/41 [==============================] - 0s 120us/step - loss: 1.1517 - accuracy: 0.0732 - val_loss: 2.0511 - val_accuracy: 0.0909
# Epoch 39/40
# 41/41 [==============================] - 0s 116us/step - loss: 1.1435 - accuracy: 0.1220 - val_loss: 2.1331 - val_accuracy: 0.0909
# Epoch 40/40
# 41/41 [==============================] - 0s 133us/step - loss: 1.1388 - accuracy: 0.1220 - val_loss: 2.2061 - val_accuracy: 0.0909
# Shape of X_test (78, 14)
# Shape of y_test (78,)
# 41/41 [==============================] - 0s 66us/step
# 11/11 [==============================] - 0s 63us/step
# Training Loss and Training Accuracy 113.36 % 9.76 %
# Validattion Loss and Validation Accuracy 220.61 % 9.09 %
# Test Loss and Test Accuracy 168.51 % 76.92 %
# Fold 2
# [ 1  2  4  5  6  9 10 11 12 14 15 16 18 19 20 23 25 27 28 29 30 31 33 34
#  36 37 38 39 41 42 43 44 45 47 49 50 51 55 56 59 60 61 63 64 65 66 67 68
#  71 72 73 77]
# train: [[ 7.  0.  0. ...  0.  0.  0.]
#  [12. 10.  1. ...  0.  0.  0.]
#  [27. 12.  3. ...  0.  0.  0.]
#  ...
#  [ 0.  6.  4. ...  0.  1.  0.]
#  [ 0. 10.  3. ...  0.  1.  0.]
#  [22.  0.  0. ...  0.  0.  1.]], test: [[ 8.  0.  0. ...  0.  0.  0.]
#  [21. 10.  4. ...  0.  0.  0.]
#  [ 8.  5.  3. ...  0.  0.  0.]
#  ...
#  [ 0.  5.  6. ...  0.  1.  0.]
#  [18.  0.  0. ...  0.  0.  1.]
#  [18.  0.  0. ...  0.  0.  1.]]
# Shape of X_train (41, 14)
# Shape of y_train (41, 12)
# Train on 41 samples, validate on 11 samples
# Epoch 1/40
# 41/41 [==============================] - 0s 3ms/step - loss: 1.1519 - accuracy: 0.0000e+00 - val_loss: 1.1302 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 41/41 [==============================] - 0s 124us/step - loss: 1.1512 - accuracy: 0.0244 - val_loss: 1.1303 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 41/41 [==============================] - 0s 135us/step - loss: 1.1506 - accuracy: 0.0976 - val_loss: 1.1303 - val_accuracy: 0.0000e+00
# Epoch 4/40
# 41/41 [==============================] - 0s 126us/step - loss: 1.1502 - accuracy: 0.0976 - val_loss: 1.1304 - val_accuracy: 0.0000e+00
# Epoch 5/40
# 41/41 [==============================] - 0s 113us/step - loss: 1.1499 - accuracy: 0.0732 - val_loss: 1.1304 - val_accuracy: 0.0000e+00
# Epoch 6/40
# 41/41 [==============================] - 0s 117us/step - loss: 1.1495 - accuracy: 0.0732 - val_loss: 1.1306 - val_accuracy: 0.0000e+00
# Epoch 7/40
# 41/41 [==============================] - 0s 115us/step - loss: 1.1490 - accuracy: 0.0732 - val_loss: 1.1307 - val_accuracy: 0.0000e+00
# Epoch 8/40
# 41/41 [==============================] - 0s 119us/step - loss: 1.1484 - accuracy: 0.0732 - val_loss: 1.1309 - val_accuracy: 0.0000e+00
# Epoch 9/40
# 41/41 [==============================] - 0s 122us/step - loss: 1.1478 - accuracy: 0.0732 - val_loss: 1.1312 - val_accuracy: 0.0000e+00
# Epoch 10/40
# 41/41 [==============================] - 0s 124us/step - loss: 1
40
# 41/41 [==============================] - 0s 120us/step - loss: 1.0670 - accuracy: 0.0732 - val_loss: 1.6102 - val_accuracy: 0.0000e+00
# Epoch 32/40
# 41/41 [==============================] - 0s 120us/step - loss: 1.0691 - accuracy: 0.0732 - val_loss: 1.7073 - val_accuracy: 0.0000e+00
# Epoch 33/40
# 41/41 [==============================] - 0s 131us/step - loss: 1.0812 - accuracy: 0.0732 - val_loss: 1.8113 - val_accuracy: 0.0000e+00
# Epoch 34/40
# 41/41 [==============================] - 0s 123us/step - loss: 1.0897 - accuracy: 0.0732 - val_loss: 1.9041 - val_accuracy: 0.0000e+00
# Epoch 35/40
# 41/41 [==============================] - 0s 124us/step - loss: 1.0873 - accuracy: 0.0732 - val_loss: 1.9720 - val_accuracy: 0.0000e+00
# Epoch 36/40
# 41/41 [==============================] - 0s 131us/step - loss: 1.0846 - accuracy: 0.0732 - val_loss: 2.0320 - val_accuracy: 0.0000e+00
# Epoch 37/40
# 41/41 [==============================] - 0s 122us/step - loss: 1.0773 - accuracy: 0.0732 - val_loss: 2.1037 - val_accuracy: 0.0000e+00
# Epoch 38/40
# 41/41 [==============================] - 0s 126us/step - loss: 1.0734 - accuracy: 0.0732 - val_loss: 2.1942 - val_accuracy: 0.0000e+00
# Epoch 39/40
# 41/41 [==============================] - 0s 121us/step - loss: 1.0819 - accuracy: 0.0732 - val_loss: 2.2998 - val_accuracy: 0.0000e+00
# Epoch 40/40
# 41/41 [==============================] - 0s 128us/step - loss: 1.0792 - accuracy: 0.0732 - val_loss: 2.3986 - val_accuracy: 0.0000e+00
# Shape of X_test (78, 14)
# Shape of y_test (78,)
# 41/41 [==============================] - 0s 43us/step
# 11/11 [==============================] - 0s 61us/step
# Training Loss and Training Accuracy 107.33 % 7.32 %
# Validattion Loss and Validation Accuracy 239.86 % 0.0 %
# Test Loss and Test Accuracy 168.51 % 76.92 %
# Fold 3
# [ 0  2  3  7  8 10 13 15 17 19 21 22 24 26 27 31 32 33 34 35 36 38 39 40
#  43 44 45 46 47 48 51 52 53 54 55 57 58 59 61 62 63 65 66 68 69 70 71 73
#  74 75 76 77]
# train: [[ 8.  0.  0. ...  0.  0.  0.]
#  [12. 10.  1. ...  0.  0.  0.]
#  [21. 10.  4. ...  0.  0.  0.]
#  ...
#  [18.  0.  0. ...  0.  0.  1.]
#  [18.  0.  0. ...  0.  0.  1.]
#  [22.  0.  0. ...  0.  0.  1.]], test: [[ 7.  0.  0. ...  0.  0.  0.]
#  [27. 12.  3. ...  0.  0.  0.]
#  [24. 14.  2. ...  0.  0.  0.]
#  ...
#  [ 0.  4.  4. ...  0.  0.  0.]
#  [ 0. 13.  0. ...  0.  0.  0.]
#  [ 0.  6.  4. ...  0.  1.  0.]]
# Shape of X_train (41, 14)
# Shape of y_train (41, 12)
# Train on 41 samples, validate on 11 samples
# Epoch 1/40
# 41/41 [==============================] - 0s 3ms/step - loss: 1.0910 - accuracy: 0.0488 - val_loss: 0.4514 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 41/41 [==============================] - 0s 153us/step - loss: 1.0905 - accuracy: 0.0732 - val_loss: 0.4512 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 41/41 [==============================] - 0s 116us/step - loss: 1.0901 - accuracy: 0.0976 - val_loss: 0.4511 - val_accuracy: 0.0909
# Epoch 4/40
# 41/41 [==============================] - 0s 119us/step - loss: 1.0898 - accuracy: 0.1463 - val_loss: 0.4509 - val_accuracy: 0.0909
# Epoch 5/40
# 41/41 [==============================] - 0s 115us/step - loss: 1.0893 - accuracy: 0.1951 - val_loss: 0.4507 - val_accuracy: 0.1818
# Epoch 6/40
# 41/41 [==============================] - 0s 114us/step - loss: 1.0889 - accuracy: 0.2927 - val_loss: 0.4505 - val_accuracy: 0.2727
# Epoch 7/40
# 41/41 [==============================] - 0s 110us/step - loss: 1
# Epoch 30/40
# 41/41 [==============================] - 0s 110us/step - loss: 1.0854 - accuracy: 0.0732 - val_loss: 0.5289 - val_accuracy: 0.0000e+00
# Epoch 31/40
# 41/41 [==============================] - 0s 114us/step - loss: 1.0856 - accuracy: 0.0488 - val_loss: 0.5475 - val_accuracy: 0.0000e+00
# Epoch 32/40
# 41/41 [==============================] - 0s 106us/step - loss: 1.0868 - accuracy: 0.0488 - val_loss: 0.5663 - val_accuracy: 0.0000e+00
# Epoch 33/40
# 41/41 [==============================] - 0s 107us/step - loss: 1.0874 - accuracy: 0.0488 - val_loss: 0.5731 - val_accuracy: 0.0000e+00
# Epoch 34/40
# 41/41 [==============================] - 0s 107us/step - loss: 1.0784 - accuracy: 0.0488 - val_loss: 0.5648 - val_accuracy: 0.0000e+00
# Epoch 35/40
# 41/41 [==============================] - 0s 118us/step - loss: 1.0762 - accuracy: 0.0488 - val_loss: 0.5406 - val_accuracy: 0.0000e+00
# Epoch 36/40
# 41/41 [==============================] - 0s 119us/step - loss: 1.0663 - accuracy: 0.0488 - val_loss: 0.4966 - val_accuracy: 0.0000e+00
# Epoch 37/40
# 41/41 [==============================] - 0s 127us/step - loss: 1.0673 - accuracy: 0.0732 - val_loss: 0.4409 - val_accuracy: 0.0000e+00
# Epoch 38/40
# 41/41 [==============================] - 0s 116us/step - loss: 1.0733 - accuracy: 0.0244 - val_loss: 0.4062 - val_accuracy: 0.0000e+00
# Epoch 39/40
# 41/41 [==============================] - 0s 121us/step - loss: 1.0921 - accuracy: 0.0244 - val_loss: 0.4005 - val_accuracy: 0.0000e+00
# Epoch 40/40
# 41/41 [==============================] - 0s 123us/step - loss: 1.0953 - accuracy: 0.0244 - val_loss: 0.4173 - val_accuracy: 0.0000e+00
# Shape of X_test (78, 14)
# Shape of y_test (78,)
# 41/41 [==============================] - 0s 40us/step
# 11/11 [==============================] - 0s 61us/step
# Training Loss and Training Accuracy 109.04 % 2.44 %
# Validattion Loss and Validation Accuracy 41.73 % 0.0 %
# Test Loss and Test Accuracy 168.51 % 76.92 %

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.00      0.00      0.00         3
#            2       0.43      1.00      0.60         3
#            3       1.00      1.00      1.00         3
#            4       0.75      1.00      0.86         3
#            5       1.00      1.00      1.00         3
#            6       1.00      0.67      0.80         3
#            7       1.00      1.00      1.00         3
#            8       0.75      1.00      0.86         3
#            9       1.00      0.67      0.80         3
#           10       0.75      1.00      0.86         3
#           11       1.00      1.00      1.00         3
#           12       0.50      0.33      0.40         3
#           13       0.60      1.00      0.75         3
#           14       0.00      0.00      0.00         3
#           15       0.60      1.00      0.75         3
#           16       0.67      0.67      0.67         3
#           17       1.00      1.00      1.00         3
#           18       1.00      0.67      0.80         3
#           19       1.00      1.00      1.00         3
#           20       0.67      0.67      0.67         3
#           21       0.50      0.33      0.40         3
#           22       1.00      0.67      0.80         3
#           23       0.75      1.00      0.86         3
#           24       0.50      0.67      0.57         3
#           25       1.00      1.00      1.00         3
#
#     accuracy                           0.77        78
#    macro avg       0.75      0.77      0.74        78
# weighted avg       0.75      0.77      0.74        78
# /Users/paulmathai/.virtualenvs/keras_tf/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
